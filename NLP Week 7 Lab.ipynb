# %%
import nltk 
nltk.download('names')
nltk.download('brown')
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Package names is already up-to-date!
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# True

# %%
# define a feature extraction function for each name
def gender_features(word):
    return{'last_letter': word[-1]}

# %%
print(gender_features('Shrek'))
# Out:
# {'last_letter': 'k'}

# %%
# resource for male and female first names
from nltk.corpus import names
print(names.words('male.txt')[:20])
print(names.words('female.txt')[:20])
# Out:
# ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot', 'Abbott', 'Abby', 'Abdel', 'Abdul', 'Abdulkarim', 'Abdullah', 'Abe', 'Abel', 'Abelard', 'Abner', 'Abraham', 'Abram', 'Ace', 'Adair', 'Adam']
# ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abby', 'Abigael', 'Abigail', 'Abigale', 'Abra', 'Acacia', 'Ada', 'Adah', 'Adaline', 'Adara', 'Addie', 'Addis', 'Adel', 'Adela']

# %%
# make list of male and female names paired with gender
namesgender = ([(name, 'male') for name in names.words('male.txt')] +
          [(name, 'female') for name in names.words('female.txt')])
print(len(namesgender))
print(namesgender[:20])
print(namesgender[7924:])
# Out:
# 7944
# [('Aamir', 'male'), ('Aaron', 'male'), ('Abbey', 'male'), ('Abbie', 'male'), ('Abbot', 'male'), ('Abbott', 'male'), ('Abby', 'male'), ('Abdel', 'male'), ('Abdul', 'male'), ('Abdulkarim', 'male'), ('Abdullah', 'male'), ('Abe', 'male'), ('Abel', 'male'), ('Abelard', 'male'), ('Abner', 'male'), ('Abraham', 'male'), ('Abram', 'male'), ('Ace', 'male'), ('Adair', 'male'), ('Adam', 'male')]
# [('Zena', 'female'), ('Zenia', 'female'), ('Zia', 'female'), ('Zilvia', 'female'), ('Zita', 'female'), ('Zitella', 'female'), ('Zoe', 'female'), ('Zola', 'female'), ('Zonda', 'female'), ('Zondra', 'female'), ('Zonnya', 'female'), ('Zora', 'female'), ('Zorah', 'female'), ('Zorana', 'female'), ('Zorina', 'female'), ('Zorine', 'female'), ('Zsa Zsa', 'female'), ('Zsazsa', 'female'), ('Zulema', 'female'), ('Zuzana', 'female')]

# %%
# put the list into random order
import random
random.shuffle(namesgender)
print(namesgender[:20])
# Out:
# [('Grant', 'male'), ('Donielle', 'female'), ('Babette', 'female'), ('Inez', 'female'), ('Max', 'male'), ('Mason', 'male'), ('Ajai', 'male'), ('Elane', 'female'), ('Edi', 'female'), ('Berni', 'female'), ('Nicole', 'female'), ('Terese', 'female'), ('Perceval', 'male'), ('Marian', 'female'), ('Torry', 'male'), ('Charmain', 'female'), ('Kingsley', 'male'), ('Carolan', 'female'), ('Quentin', 'male'), ('Christina', 'female')]

# %%
# separate the names into training and test
train_names = namesgender[500:]
test_names = namesgender[:500]

# %%
# use our features to train a classify and test on the development test set
train_set = [(gender_features(n), g) for (n, g) in train_names]
test_set = [(gender_features(n), g) for (n, g) in test_names]
print(train_set[:20])
# Out:
# [({'last_letter': 'd'}, 'male'), ({'last_letter': 's'}, 'male'), ({'last_letter': 'd'}, 'male'), ({'last_letter': 'n'}, 'male'), ({'last_letter': 'i'}, 'female'), ({'last_letter': 't'}, 'male'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'y'}, 'female'), ({'last_letter': 's'}, 'male'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'h'}, 'male'), ({'last_letter': 's'}, 'male'), ({'last_letter': 'y'}, 'male'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'h'}, 'male'), ({'last_letter': 't'}, 'male'), ({'last_letter': 'n'}, 'female'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'e'}, 'female')]

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
# classify new instances
print(classifier.classify(gender_features('Neo')))
print(classifier.classify(gender_features('Trinity')))
# Out:
# male
# female

# %%
# classify accuracy function runs the classifier on the test set and reports
#   comparisons between predicted labels and actual/gold labels
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.758

# %%
# this function available for naive bayes classifiers
print(classifier.show_most_informative_features(20))
# Out:
# Most Informative Features
#              last_letter = 'a'            female : male   =     33.1 : 1.0
#              last_letter = 'k'              male : female =     32.3 : 1.0
#              last_letter = 'f'              male : female =     16.7 : 1.0
#              last_letter = 'p'              male : female =     11.9 : 1.0
#              last_letter = 'v'              male : female =     10.5 : 1.0
#              last_letter = 'd'              male : female =      9.5 : 1.0
#              last_letter = 'm'              male : female =      8.8 : 1.0
#              last_letter = 'o'              male : female =      8.2 : 1.0
#              last_letter = 'r'              male : female =      8.0 : 1.0
#              last_letter = 'w'              male : female =      5.1 : 1.0
#              last_letter = 'g'              male : female =      4.9 : 1.0
#              last_letter = 'z'              male : female =      4.3 : 1.0
#              last_letter = 's'              male : female =      4.2 : 1.0
#              last_letter = 't'              male : female =      4.2 : 1.0
#              last_letter = 'b'              male : female =      4.1 : 1.0
#              last_letter = 'j'              male : female =      4.0 : 1.0
#              last_letter = 'i'            female : male   =      3.6 : 1.0
#              last_letter = 'u'              male : female =      3.6 : 1.0
#              last_letter = 'n'              male : female =      2.1 : 1.0
#              last_letter = 'l'              male : female =      1.8 : 1.0
# None

# %%
# define a function that will compare the classifier labels with the gold standard labels
def geterrors(test):
    errors = []
    for (name, tag) in test:
        guess = classifier.classify(gender_features(name))
        if guess != tag:
            errors.append( (tag, guess, name) )
    return errors

errors = geterrors(test_names)
print(len(errors))
# Out:
# 109

# %%
# define a function to print the errors
def printerrors(errors):
    for (tag, guess, name) in sorted(errors):
        print('correct={:<8s} guess={:<8s} name={:<30s}'.format(tag, guess, name))

printerrors(errors)
# Out:
# correct=female   guess=male     name=Annabell
# correct=female   guess=male     name=Arden
# correct=female   guess=male     name=Arlen
# correct=female   guess=male     name=Aurel
# correct=female   guess=male     name=Beitris
# correct=female   guess=male     name=Brandais
# correct=female   guess=male     name=Calypso
# correct=female   guess=male     name=Cameo
# correct=female   guess=male     name=Carilyn
# correct=female   guess=male     name=Carolan
# correct=female   guess=male     name=Caryl
# correct=female   guess=male     name=Charil
# correct=female   guess=male     name=Charleen
# correct=female   guess=male     name=Charmain
# correct=female   guess=male     name=Christal
# correct=female   guess=male     name=Chrysler
# correct=female   guess=male     name=Coral
# correct=female   guess=male     name=Coreen
# correct=female   guess=male     name=Evelyn
# correct=female   guess=male     name=Frances
# correct=female   guess=male     name=Germain
# correct=female   guess=male     name=Hester
# correct=female   guess=male     name=Inez
# correct=female   guess=male     name=Jackquelin
# correct=female   guess=male     name=Janeen
# correct=female   guess=male     name=Kaster
# correct=female   guess=male     name=Katheleen
# correct=female   guess=male     name=Keren
# correct=female   guess=male     name=Kristel
# correct=female   guess=male     name=Kristien
# correct=female   guess=male     name=Mair
# correct=female   guess=male     name=Marian
# correct=female   guess=male     name=Marillin
# correct=female   guess=male     name=Maryann
# correct=female   guess=male     name=Marylin
# correct=female   guess=male     name=Meagan
# correct=female   guess=male     name=Megen
# correct=female   guess=male     name=Meggan
# correct=female   guess=male     name=Melisent
# correct=female   guess=male     name=Meris
# correct=female   guess=male     name=Miran
# correct=female   guess=male     name=Morgan
# correct=female   guess=male     name=Nell
# correct=female   guess=male     name=Phylis
# correct=female   guess=male     name=Reiko
# correct=female   guess=male     name=Shaun
# correct=female   guess=male     name=Shell
# correct=female   guess=male     name=Vin
# correct=female   guess=male     name=Winifred
# correct=female   guess=male     name=Winnifred
# correct=female   guess=male     name=Wren
# correct=male     guess=female   name=Aditya
# correct=male     guess=female   name=Ajai
# correct=male     guess=female   name=Aldrich
# correct=male     guess=female   name=Antoni
# correct=male     guess=female   name=Augustine
# correct=male     guess=female   name=Avi
# correct=male     guess=female   name=Bartolomei
# correct=male     guess=female   name=Benny
# correct=male     guess=female   name=Bernie
# correct=male     guess=female   name=Bucky
# correct=male     guess=female   name=Cammy
# correct=male     guess=female   name=Carey
# correct=male     guess=female   name=Charley
# correct=male     guess=female   name=Chrisy
# correct=male     guess=female   name=Clemente
# correct=male     guess=female   name=Corby
# correct=male     guess=female   name=Danny
# correct=male     guess=female   name=Emery
# correct=male     guess=female   name=Filipe
# correct=male     guess=female   name=Fonsie
# correct=male     guess=female   name=Geoffry
# correct=male     guess=female   name=Gere
# correct=male     guess=female   name=Guthrey
# correct=male     guess=female   name=Hamish
# correct=male     guess=female   name=Jackie
# correct=male     guess=female   name=Jeffery
# correct=male     guess=female   name=Jermayne
# correct=male     guess=female   name=Jodie
# correct=male     guess=female   name=Jule
# correct=male     guess=female   name=Kingsley
# correct=male     guess=female   name=Lawerence
# correct=male     guess=female   name=Lefty
# correct=male     guess=female   name=Leigh
# correct=male     guess=female   name=Luke
# correct=male     guess=female   name=Max
# correct=male     guess=female   name=Mendie
# correct=male     guess=female   name=Meredith
# correct=male     guess=female   name=Moise
# correct=male     guess=female   name=Murphy
# correct=male     guess=female   name=Nevile
# correct=male     guess=female   name=Paddy
# correct=male     guess=female   name=Pierce
# correct=male     guess=female   name=Quincy
# correct=male     guess=female   name=Reggie
# correct=male     guess=female   name=Roddie
# correct=male     guess=female   name=Rolfe
# correct=male     guess=female   name=Serge
# correct=male     guess=female   name=Seth
# correct=male     guess=female   name=Simone
# correct=male     guess=female   name=Skippy
# correct=male     guess=female   name=Tome
# correct=male     guess=female   name=Torry
# correct=male     guess=female   name=Uriah
# correct=male     guess=female   name=Vijay
# correct=male     guess=female   name=Worthy
# correct=male     guess=female   name=Yuri
# correct=male     guess=female   name=Zeke
# correct=male     guess=female   name=Zolly

# %% [markdown]
# ##Exercise 1: Define a new feature extraction function that includes features for two-letter suffixes

# %%
def gender_features3(word):
  return {'suffix1': word[-1],'suffix2': word[-2]}

# %%
print(gender_features3('Shrek'))
# Out:
# {'suffix1': 'k', 'suffix2': 'e'}

# %%
# use our features to train a classify and test on the development test set
train_set = [(gender_features3(n), g) for (n, g) in train_names]
test_set = [(gender_features3(n), g) for (n, g) in test_names]
print(train_set[:20])
# Out:
# [({'suffix1': 'e', 'suffix2': 'i'}, 'female'), ({'suffix1': 'a', 'suffix2': 'r'}, 'female'), ({'suffix1': 'a', 'suffix2': 'n'}, 'female'), ({'suffix1': 'e', 'suffix2': 'b'}, 'male'), ({'suffix1': 'g', 'suffix2': 'e'}, 'male'), ({'suffix1': 'n', 'suffix2': 'i'}, 'female'), ({'suffix1': 'a', 'suffix2': 'd'}, 'female'), ({'suffix1': 'n', 'suffix2': 'a'}, 'male'), ({'suffix1': 's', 'suffix2': 'd'}, 'male'), ({'suffix1': 's', 'suffix2': 'a'}, 'male'), ({'suffix1': 'a', 'suffix2': 'h'}, 'female'), ({'suffix1': 'i', 'suffix2': 'n'}, 'female'), ({'suffix1': 'a', 'suffix2': 'n'}, 'female'), ({'suffix1': 'e', 'suffix2': 's'}, 'female'), ({'suffix1': 'e', 'suffix2': 't'}, 'female'), ({'suffix1': 'a', 'suffix2': 'e'}, 'female'), ({'suffix1': 's', 'suffix2': 'i'}, 'male'), ({'suffix1': 'e', 'suffix2': 'l'}, 'male'), ({'suffix1': 't', 'suffix2': 'r'}, 'male'), ({'suffix1': 'e', 'suffix2': 'k'}, 'female')]

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
# classify accuracy function runs the classifier on the test set and reports
#   comparisons between predicted labels and actual/gold labels
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.766

# %%
# this function available for naive bayes classifiers
print(classifier.show_most_informative_features(20))
# Out:
# Most Informative Features
#                  suffix1 = 'a'            female : male   =     34.3 : 1.0
#                  suffix1 = 'k'              male : female =     29.5 : 1.0
#                  suffix1 = 'f'              male : female =     16.1 : 1.0
#                  suffix1 = 'p'              male : female =     12.0 : 1.0
#                  suffix1 = 'v'              male : female =      9.9 : 1.0
#                  suffix1 = 'd'              male : female =      9.7 : 1.0
#                  suffix1 = 'o'              male : female =      8.9 : 1.0
#                  suffix1 = 'm'              male : female =      8.4 : 1.0
#                  suffix2 = 'o'              male : female =      7.1 : 1.0
#                  suffix1 = 'r'              male : female =      7.1 : 1.0
#                  suffix2 = 'u'              male : female =      6.9 : 1.0
#                  suffix1 = 'z'              male : female =      5.6 : 1.0
#                  suffix1 = 'w'              male : female =      5.1 : 1.0
#                  suffix2 = 'E'              male : female =      5.1 : 1.0
#                  suffix1 = 'g'              male : female =      5.0 : 1.0
#                  suffix1 = 's'              male : female =      4.0 : 1.0
#                  suffix1 = 't'              male : female =      3.8 : 1.0
#                  suffix1 = 'i'            female : male   =      3.7 : 1.0
#                  suffix1 = 'b'              male : female =      3.7 : 1.0
#                  suffix2 = 'y'            female : male   =      3.6 : 1.0
# None

# %%
# define a function that will compare the classifier labels with the gold standard labels
def geterrors(test):
    errors = []
    for (name, tag) in test:
        guess = classifier.classify(gender_features3(name))
        if guess != tag:
            errors.append( (tag, guess, name) )
    return errors

errors = geterrors(test_names)
print(len(errors))
# Out:
# 117

# %%
def gender_features2(word):
  return {'prefix1': word[0],'prefix2': word[1], 'suffix1': word[-1],'suffix2': word[-2]}

# %%
print(gender_features2('Shrek'))
# Out:
# {'prefix1': 'S', 'prefix2': 'h', 'suffix1': 'k', 'suffix2': 'e'}

# %%
# use our features to train a classify and test on the development test set
train_set = [(gender_features2(n), g) for (n, g) in train_names]
test_set = [(gender_features2(n), g) for (n, g) in test_names]
print(train_set[:20])
# Out:
# [({'prefix1': 'D', 'prefix2': 'a', 'suffix1': 'e', 'suffix2': 'i'}, 'female'), ({'prefix1': 'A', 'prefix2': 's', 'suffix1': 'a', 'suffix2': 'r'}, 'female'), ({'prefix1': 'M', 'prefix2': 'o', 'suffix1': 'a', 'suffix2': 'n'}, 'female'), ({'prefix1': 'A', 'prefix2': 'b', 'suffix1': 'e', 'suffix2': 'b'}, 'male'), ({'prefix1': 'O', 'prefix2': 'l', 'suffix1': 'g', 'suffix2': 'e'}, 'male'), ({'prefix1': 'M', 'prefix2': 'u', 'suffix1': 'n', 'suffix2': 'i'}, 'female'), ({'prefix1': 'H', 'prefix2': 'a', 'suffix1': 'a', 'suffix2': 'd'}, 'female'), ({'prefix1': 'S', 'prefix2': 'h', 'suffix1': 'n', 'suffix2': 'a'}, 'male'), ({'prefix1': 'R', 'prefix2': 'e', 'suffix1': 's', 'suffix2': 'd'}, 'male'), ({'prefix1': 'B', 'prefix2': 'a', 'suffix1': 's', 'suffix2': 'a'}, 'male'), ({'prefix1': 'L', 'prefix2': 'e', 'suffix1': 'a', 'suffix2': 'h'}, 'female'), ({'prefix1': 'W', 'prefix2': 'i', 'suffix1': 'i', 'suffix2': 'n'}, 'female'), ({'prefix1': 'T', 'prefix2': 'r', 'suffix1': 'a', 'suffix2': 'n'}, 'female'), ({'prefix1': 'E', 'prefix2': 'l', 'suffix1': 'e', 'suffix2': 's'}, 'female'), ({'prefix1': 'G', 'prefix2': 'a', 'suffix1': 'e', 'suffix2': 't'}, 'female'), ({'prefix1': 'D', 'prefix2': 'u', 'suffix1': 'a', 'suffix2': 'e'}, 'female'), ({'prefix1': 'L', 'prefix2': 'e', 'suffix1': 's', 'suffix2': 'i'}, 'male'), ({'prefix1': 'L', 'prefix2': 'y', 'suffix1': 'e', 'suffix2': 'l'}, 'male'), ({'prefix1': 'W', 'prefix2': 'i', 'suffix1': 't', 'suffix2': 'r'}, 'male'), ({'prefix1': 'E', 'prefix2': 'l', 'suffix1': 'e', 'suffix2': 'k'}, 'female')]

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
# classify accuracy function runs the classifier on the test set and reports
#   comparisons between predicted labels and actual/gold labels
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.782

# %%
# this function available for naive bayes classifiers
print(classifier.show_most_informative_features(20))
# Out:
# Most Informative Features
#                  suffix1 = 'a'            female : male   =     34.3 : 1.0
#                  suffix1 = 'k'              male : female =     29.5 : 1.0
#                  suffix1 = 'f'              male : female =     16.1 : 1.0
#                  suffix1 = 'p'              male : female =     12.0 : 1.0
#                  suffix1 = 'v'              male : female =      9.9 : 1.0
#                  suffix1 = 'd'              male : female =      9.7 : 1.0
#                  prefix2 = 'k'              male : female =      9.2 : 1.0
#                  suffix1 = 'o'              male : female =      8.9 : 1.0
#                  suffix1 = 'm'              male : female =      8.4 : 1.0
#                  prefix2 = 'z'              male : female =      7.2 : 1.0
#                  suffix2 = 'o'              male : female =      7.1 : 1.0
#                  suffix1 = 'r'              male : female =      7.1 : 1.0
#                  suffix2 = 'u'              male : female =      6.9 : 1.0
#                  suffix1 = 'z'              male : female =      5.6 : 1.0
#                  suffix1 = 'w'              male : female =      5.1 : 1.0
#                  suffix2 = 'E'              male : female =      5.1 : 1.0
#                  suffix1 = 'g'              male : female =      5.0 : 1.0
#                  prefix1 = 'W'              male : female =      4.7 : 1.0
#                  suffix1 = 's'              male : female =      4.0 : 1.0
#                  prefix2 = 'j'              male : female =      4.0 : 1.0
# None

# %%
# define a function that will compare the classifier labels with the gold standard labels
def geterrors(test):
    errors = []
    for (name, tag) in test:
        guess = classifier.classify(gender_features3(name))
        if guess != tag:
            errors.append( (tag, guess, name) )
    return errors

errors = geterrors(test_names)
print(len(errors))
# Out:
# 117

# %%
def gender_features4(word):
  if len(word) >=2:
    return {'prefix1': word[0],
            'last_letter': word[-1], 
            'last_two_letters': word[-2:]}
  elif len(word) <=2:
    return
    {'last_two_letters': word[-2:]}

# %%
# use our features to train a classify and test on the development test set
train_set = [(gender_features4(n), g) for (n, g) in train_names]
test_set = [(gender_features4(n), g) for (n, g) in test_names]
print(train_set[:20])
# Out:
# [({'prefix1': 'D', 'last_letter': 'e', 'last_two_letters': 'ie'}, 'female'), ({'prefix1': 'A', 'last_letter': 'a', 'last_two_letters': 'ra'}, 'female'), ({'prefix1': 'M', 'last_letter': 'a', 'last_two_letters': 'na'}, 'female'), ({'prefix1': 'A', 'last_letter': 'e', 'last_two_letters': 'be'}, 'male'), ({'prefix1': 'O', 'last_letter': 'g', 'last_two_letters': 'eg'}, 'male'), ({'prefix1': 'M', 'last_letter': 'n', 'last_two_letters': 'in'}, 'female'), ({'prefix1': 'H', 'last_letter': 'a', 'last_two_letters': 'da'}, 'female'), ({'prefix1': 'S', 'last_letter': 'n', 'last_two_letters': 'an'}, 'male'), ({'prefix1': 'R', 'last_letter': 's', 'last_two_letters': 'ds'}, 'male'), ({'prefix1': 'B', 'last_letter': 's', 'last_two_letters': 'as'}, 'male'), ({'prefix1': 'L', 'last_letter': 'a', 'last_two_letters': 'ha'}, 'female'), ({'prefix1': 'W', 'last_letter': 'i', 'last_two_letters': 'ni'}, 'female'), ({'prefix1': 'T', 'last_letter': 'a', 'last_two_letters': 'na'}, 'female'), ({'prefix1': 'E', 'last_letter': 'e', 'last_two_letters': 'se'}, 'female'), ({'prefix1': 'G', 'last_letter': 'e', 'last_two_letters': 'te'}, 'female'), ({'prefix1': 'D', 'last_letter': 'a', 'last_two_letters': 'ea'}, 'female'), ({'prefix1': 'L', 'last_letter': 's', 'last_two_letters': 'is'}, 'male'), ({'prefix1': 'L', 'last_letter': 'e', 'last_two_letters': 'le'}, 'male'), ({'prefix1': 'W', 'last_letter': 't', 'last_two_letters': 'rt'}, 'male'), ({'prefix1': 'E', 'last_letter': 'e', 'last_two_letters': 'ke'}, 'female')]

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
# classify accuracy function runs the classifier on the test set and reports
#   comparisons between predicted labels and actual/gold labels
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.818

# %%
# define a function to print the errors
def printerrors(errors):
    for (tag, guess, name) in sorted(errors):
        print('correct={:<8s} guess={:<8s} name={:<30s}'.format(tag, guess, name))

printerrors(errors)
# Out:
# correct=female   guess=male     name=Arden
# correct=female   guess=male     name=Arlen
# correct=female   guess=male     name=Aurel
# correct=female   guess=male     name=Beitris
# correct=female   guess=male     name=Brandais
# correct=female   guess=male     name=Briney
# correct=female   guess=male     name=Britaney
# correct=female   guess=male     name=Calypso
# correct=female   guess=male     name=Cameo
# correct=female   guess=male     name=Carolan
# correct=female   guess=male     name=Charleen
# correct=female   guess=male     name=Charmain
# correct=female   guess=male     name=Christal
# correct=female   guess=male     name=Chrysler
# correct=female   guess=male     name=Coral
# correct=female   guess=male     name=Cordey
# correct=female   guess=male     name=Coreen
# correct=female   guess=male     name=Dolley
# correct=female   guess=male     name=Frances
# correct=female   guess=male     name=Germain
# correct=female   guess=male     name=Hannah
# correct=female   guess=male     name=Hester
# correct=female   guess=male     name=Inez
# correct=female   guess=male     name=Jackquelin
# correct=female   guess=male     name=Janeen
# correct=female   guess=male     name=Kaster
# correct=female   guess=male     name=Katheleen
# correct=female   guess=male     name=Kelcy
# correct=female   guess=male     name=Keren
# correct=female   guess=male     name=Kristel
# correct=female   guess=male     name=Kristien
# correct=female   guess=male     name=Leilah
# correct=female   guess=male     name=Lindsay
# correct=female   guess=male     name=Mair
# correct=female   guess=male     name=Malkah
# correct=female   guess=male     name=Marian
# correct=female   guess=male     name=Marillin
# correct=female   guess=male     name=Marylin
# correct=female   guess=male     name=Max
# correct=female   guess=male     name=Meagan
# correct=female   guess=male     name=Megen
# correct=female   guess=male     name=Meggan
# correct=female   guess=male     name=Meris
# correct=female   guess=male     name=Miran
# correct=female   guess=male     name=Morgan
# correct=female   guess=male     name=Nonnah
# correct=female   guess=male     name=Phylis
# correct=female   guess=male     name=Reiko
# correct=female   guess=male     name=Shaun
# correct=female   guess=male     name=Shirah
# correct=female   guess=male     name=Vin
# correct=female   guess=male     name=Winifred
# correct=female   guess=male     name=Winnifred
# correct=female   guess=male     name=Wren
# correct=female   guess=male     name=Zarah
# correct=male     guess=female   name=Aditya
# correct=male     guess=female   name=Ajai
# correct=male     guess=female   name=Antoni
# correct=male     guess=female   name=Augustine
# correct=male     guess=female   name=Avi
# correct=male     guess=female   name=Bartolomei
# correct=male     guess=female   name=Benny
# correct=male     guess=female   name=Bernie
# correct=male     guess=female   name=Bucky
# correct=male     guess=female   name=Cammy
# correct=male     guess=female   name=Carroll
# correct=male     guess=female   name=Chrisy
# correct=male     guess=female   name=Clement
# correct=male     guess=female   name=Clemente
# correct=male     guess=female   name=Corby
# correct=male     guess=female   name=Danny
# correct=male     guess=female   name=Douglass
# correct=male     guess=female   name=Elihu
# correct=male     guess=female   name=Emery
# correct=male     guess=female   name=Filipe
# correct=male     guess=female   name=Fonsie
# correct=male     guess=female   name=Forest
# correct=male     guess=female   name=Geoffry
# correct=male     guess=female   name=Gere
# correct=male     guess=female   name=Grant
# correct=male     guess=female   name=Hamish
# correct=male     guess=female   name=Higgins
# correct=male     guess=female   name=Jackie
# correct=male     guess=female   name=Jeffery
# correct=male     guess=female   name=Jermayne
# correct=male     guess=female   name=Jodie
# correct=male     guess=female   name=Jule
# correct=male     guess=female   name=Lawerence
# correct=male     guess=female   name=Lefty
# correct=male     guess=female   name=Luke
# correct=male     guess=female   name=Mendie
# correct=male     guess=female   name=Meredith
# correct=male     guess=female   name=Mikhail
# correct=male     guess=female   name=Millicent
# correct=male     guess=female   name=Moise
# correct=male     guess=female   name=Murphy
# correct=male     guess=female   name=Nathanil
# correct=male     guess=female   name=Nevile
# correct=male     guess=female   name=Niall
# correct=male     guess=female   name=Paddy
# correct=male     guess=female   name=Pierce
# correct=male     guess=female   name=Reggie
# correct=male     guess=female   name=Roddie
# correct=male     guess=female   name=Rolfe
# correct=male     guess=female   name=Serge
# correct=male     guess=female   name=Seth
# correct=male     guess=female   name=Simone
# correct=male     guess=female   name=Stu
# correct=male     guess=female   name=Tarrant
# correct=male     guess=female   name=Tome
# correct=male     guess=female   name=Torry
# correct=male     guess=female   name=Wiatt
# correct=male     guess=female   name=Willmott
# correct=male     guess=female   name=Worthy
# correct=male     guess=female   name=Yuri
# correct=male     guess=female   name=Zeke
# correct=male     guess=female   name=Zolly

# %% [markdown]
# ##Lab Part 2

# %%
## classify part of speech based on sentence context
from nltk.corpus import brown

# define features for the "i"th word in the sentence, including three types of suffix 
#     and one pre-word
# the pos features function takes the sentence of untagged words and the index of a word i
#   it creates features for word i, including the previous word i-1
def pos_features(sentence, i):    
    features = {"suffix(1)": sentence[i][-1:],
		    "suffix(2)": sentence[i][-2:],
		    "suffix(3)": sentence[i][-3:]}
    if i == 0:
        features["prev-word"] = "<START>"
    else:
        features["prev-word"] = sentence[i-1]
    return features

# %%
# look at features of a specific word in a specific sentence
# first sentence of brown corpus
sentence0 = brown.sents()[0]
print(sentence0)
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.']

# %%
# word 8 of sentence 0
print(sentence0[8])
# Out:
# investigation

# %%
# pos features of the word 8 
print(pos_features(sentence0, 8))
# Out:
# {'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ion', 'prev-word': 'an'}

# %%
# get the POS tagged sentences with categories of news
tagged_sents = brown.tagged_sents(categories='news')
tag_sent0 = tagged_sents[0]
tag_sent0
# Out:
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('an', 'AT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ("Atlanta's", 'NP$'),
#  ('recent', 'JJ'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', '``'),
#  ('no', 'AT'),
#  ('evidence', 'NN'),
#  ("''", "''"),
#  ('that', 'CS'),
#  ('any', 'DTI'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN'),
#  ('.', '.')]

# %%
# the function nltk.tag.untag will take the tags off
nltk.tag.untag(tag_sent0)
# Out:
# ['The',
#  'Fulton',
#  'County',
#  'Grand',
#  'Jury',
#  'said',
#  'Friday',
#  'an',
#  'investigation',
#  'of',
#  "Atlanta's",
#  'recent',
#  'primary',
#  'election',
#  'produced',
#  '``',
#  'no',
#  'evidence',
#  "''",
#  'that',
#  'any',
#  'irregularities',
#  'took',
#  'place',
#  '.']

# %%
# the python enumerate function generates an index number for each item in a list
for i,(word,tag) in enumerate(tag_sent0):
    print (i, word, tag)
# Out:
# 0 The AT
# 1 Fulton NP-TL
# 2 County NN-TL
# 3 Grand JJ-TL
# 4 Jury NN-TL
# 5 said VBD
# 6 Friday NR
# 7 an AT
# 8 investigation NN
# 9 of IN
# 10 Atlanta's NP$
# 11 recent JJ
# 12 primary NN
# 13 election NN
# 14 produced VBD
# 15 `` ``
# 16 no AT
# 17 evidence NN
# 18 '' ''
# 19 that CS
# 20 any DTI
# 21 irregularities NNS
# 22 took VBD
# 23 place NN
# 24 . .

# %%
# get feature sets of words appearing in the corpus, from untagged sentences.
# and then get their tags from corresponding tagged sentence
# use the Python function enumerate to pair the index numbers with sentence words 
#   for the pos features function
featuresets = []
for tagged_sent in tagged_sents:
	untagged_sent = nltk.tag.untag(tagged_sent)
	for i, (word, tag) in enumerate(tagged_sent):
		featuresets.append( (pos_features(untagged_sent, i), tag) )

# %%
# look at the feature sets of the first 10 words
for f in featuresets[:10]:
	print (f)
# Out:
# ({'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'The', 'prev-word': '<START>'}, 'AT')
# ({'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ton', 'prev-word': 'The'}, 'NP-TL')
# ({'suffix(1)': 'y', 'suffix(2)': 'ty', 'suffix(3)': 'nty', 'prev-word': 'Fulton'}, 'NN-TL')
# ({'suffix(1)': 'd', 'suffix(2)': 'nd', 'suffix(3)': 'and', 'prev-word': 'County'}, 'JJ-TL')
# ({'suffix(1)': 'y', 'suffix(2)': 'ry', 'suffix(3)': 'ury', 'prev-word': 'Grand'}, 'NN-TL')
# ({'suffix(1)': 'd', 'suffix(2)': 'id', 'suffix(3)': 'aid', 'prev-word': 'Jury'}, 'VBD')
# ({'suffix(1)': 'y', 'suffix(2)': 'ay', 'suffix(3)': 'day', 'prev-word': 'said'}, 'NR')
# ({'suffix(1)': 'n', 'suffix(2)': 'an', 'suffix(3)': 'an', 'prev-word': 'Friday'}, 'AT')
# ({'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ion', 'prev-word': 'an'}, 'NN')
# ({'suffix(1)': 'f', 'suffix(2)': 'of', 'suffix(3)': 'of', 'prev-word': 'investigation'}, 'IN')

# %%
# using naive Bayesian as classifier
# split data into a training set and a test set, using a 90%/10% split
size = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[size:], featuresets[:size]
print(len(train_set))
print(len(test_set))
# Out:
# 90499
# 10055

# %%
# train classifier on the training set
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
# evaluate the accuracy (this will take a little while)
print(nltk.classify.accuracy(classifier, test_set))
# the result is reasonable for features without the previous tag
# Out:
# 0.7891596220785678

# %% [markdown]
# ## Part 3

# %%
### classify documents based on keywords
from nltk.corpus import movie_reviews
import random

# %%
# movie reviews are labeled either positive or negative (by human annotators)
print(movie_reviews.categories())
# Out:
# ['neg', 'pos']

# %%
# for each document in movie_reviews, get its words and category (positive/negative)
documents = [(list(movie_reviews.words(fileid)), category)
              for category in movie_reviews.categories()
              for fileid in movie_reviews.fileids(category)]
print(len(documents))

random.shuffle(documents)
# Out:
# 2000

# %%
# look at the first document - consists of a list of all the words in the review
# followed by the category
print(documents[0])
# Out:
# (['assume', 'nothing', '.', 'the', 'phrase', 'is', 'perhaps', 'one', 'of', 'the', 'most', 'used', 'of', 'the', '1990', "'", 's', ',', 'as', 'first', 'impressions', 'and', 'rumors', 'are', 'hardly', 'ever', 'what', 'they', 'seem', 'to', 'be', '.', 'the', 'phrase', 'especially', 'goes', 'for', 'oscar', 'novak', ',', 'an', 'architect', 'who', 'is', 'the', 'main', 'focus', 'of', 'three', 'to', 'tango', ',', 'a', 'delightful', ',', 'funny', 'romantic', 'comedy', 'about', 'assumptions', 'and', 'being', 'yourself', '.', 'novak', '(', 'matthew', 'perry', ')', ',', 'a', 'shy', ',', 'clumsy', ',', 'chicago', 'based', 'architect', ',', 'along', 'with', 'openly', 'gay', 'partner', ',', 'peter', 'steinberg', '(', 'oliver', 'platt', ')', ',', 'fights', 'for', 'projects', 'day', 'in', 'and', 'day', 'out', '.', 'one', 'of', 'these', 'is', 'the', 'job', 'of', 'restoring', 'a', 'popular', 'building', 'for', 'charles', 'newman', '(', 'dylan', 'mcdermott', ')', ',', 'a', 'rich', ',', 'well', '-', 'known', 'businessman', '.', 'charles', 'immediately', 'takes', 'a', 'liking', 'to', 'oscar', ',', 'as', 'he', 'enjoys', 'his', 'personality', 'and', 'sense', 'of', 'humor', '.', 'seeing', 'oscar', 'as', 'someone', 'he', 'could', 'trust', ',', 'charles', 'asks', 'him', 'to', 'watch', 'his', 'girlfriend', ',', 'an', 'unpredictable', ',', 'adventurous', 'girl', 'named', 'amy', 'post', '(', 'neve', 'campbell', ')', ',', 'who', 'makes', 'a', 'living', 'by', 'blowing', 'glass', '.', 'charles', 'wants', 'to', 'know', 'who', 'she', 'talks', 'to', ',', 'what', 'she', 'does', ',', 'and', 'where', 'she', 'goes', '.', 'the', 'point', '?', 'to', 'make', 'sure', 'she', "'", 's', 'not', 'seeing', 'someone', 'else', ',', 'of', 'course', '.', 'oscar', 'gladly', 'takes', 'the', 'job', ',', 'and', 'meets', 'amy', 'at', 'an', 'art', 'show', 'of', 'hers', ',', 'and', 'sparks', 'fly', 'between', 'the', 'two', 'from', 'the', 'get', 'go', '.', 'oscar', 'feels', 'he', 'has', 'found', 'the', 'one', 'meant', 'for', 'him', ',', 'and', 'he', 'is', 'content', 'with', 'the', 'idea', 'of', 'being', 'with', 'amy', '.', 'well', ',', 'another', 'popular', 'phrase', 'of', 'the', '90', "'", 's', 'is', '"', 'all', 'good', 'things', 'must', 'come', 'to', 'an', 'end', ',', '"', 'and', 'this', 'stays', 'true', 'for', 'oscar', 'as', 'well', '.', 'charles', 'walks', 'in', 'on', 'amy', 'and', 'oscar', 'having', 'a', 'drink', 'one', 'night', ',', 'as', 'oscar', 'and', 'amy', 'have', 'become', 'great', 'friends', ',', 'but', 'he', 'doesn', "'", 't', 'seem', 'to', 'mind', '.', 'why', 'is', 'this', '?', 'he', 'thinks', 'oscar', 'is', 'gay', '.', 'he', "'", 's', 'not', 'afraid', 'to', 'share', 'this', 'with', 'him', 'either', '.', 'oscar', 'stands', 'in', 'shock', 'after', 'the', 'words', ',', '"', 'i', 'swear', 'if', 'you', 'weren', "'", 't', 'gay', 'oscar', ',', 'i', "'", 'd', 'have', 'to', 'kill', 'you', ',', '"', 'are', 'muttered', 'flamboyantly', 'from', 'charles', "'", 'mouth', '.', 'the', 'word', 'spreads', 'instantly', 'through', 'town', '.', 'will', 'oscar', '"', 'come', 'out', '"', 'of', 'his', 'supposed', 'gayness', ',', 'or', 'will', 'he', 'tell', 'everyone', 'that', 'he', 'isn', "'", 't', '?', 'one', 'would', 'immediately', 'think', 'he', 'would', 'deny', 'the', 'fact', ',', 'but', 'numerous', 'occurrences', 'come', 'to', 'oscar', ',', 'which', 'result', 'in', 'the', 'fact', 'that', 'if', 'he', 'denies', 'the', 'fact', ',', 'he', 'could', 'lose', 'his', 'job', 'with', 'charles', '.', 'matthew', 'perry', 'doesn', "'", 't', 'escape', 'his', 'character', 'as', 'chandler', 'on', 'the', 'already', 'classic', 't', '.', 'v', '.', 'comedy', '"', 'friends', ',', '"', 'as', 'both', 'oscar', 'novak', 'and', 'chandler', 'are', 'clueless', ',', 'shy', ',', 'and', 'sensitive', '.', 'nonetheless', ',', 'perry', 'is', 'hilarious', 'here', ',', 'and', 'shows', 'that', 'he', 'can', 'handle', 'drama', ',', 'as', 'obviously', ',', 'his', 'character', 'suffers', 'quite', 'a', 'bit', 'here', '.', 'it', "'", 's ...

# %%
## use words from all documents to define the word vector for features
# get all words from all movie_reviews and put into a frequency distribution
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
print(len(all_words))
# Out:
# 39768

# %%
# get the 2000 most frequently appearing keywords in the corpus
word_items = all_words.most_common(3500)
word_features = [word for (word, freq) in word_items]   # just the words

# %%
# look at the first 100 words
print(word_features[:100])
# Out:
# [',', 'the', '.', 'a', 'and', 'of', 'to', "'", 'is', 'in', 's', '"', 'it', 'that', '-', ')', '(', 'as', 'with', 'for', 'his', 'this', 'film', 'i', 'he', 'but', 'on', 'are', 't', 'by', 'be', 'one', 'movie', 'an', 'who', 'not', 'you', 'from', 'at', 'was', 'have', 'they', 'has', 'her', 'all', '?', 'there', 'like', 'so', 'out', 'about', 'up', 'more', 'what', 'when', 'which', 'or', 'she', 'their', ':', 'some', 'just', 'can', 'if', 'we', 'him', 'into', 'even', 'only', 'than', 'no', 'good', 'time', 'most', 'its', 'will', 'story', 'would', 'been', 'much', 'character', 'also', 'get', 'other', 'do', 'two', 'well', 'them', 'very', 'characters', ';', 'first', '--', 'after', 'see', '!', 'way', 'because', 'make', 'life']

# %%
# define features (keywords) of a document
# each feature is 'contains(keyword)' and is true or false depending
# on whether that keyword is in the document
def document_features(document, word_features):
	document_words = set(document)
	features = {}
	for word in word_features:
		features['V_%s' % word] = (word in document_words)
	return features

# %%
# get features sets for a document, including keyword features and category feature
featuresets = [(document_features(d, word_features), c) for (d,c) in documents]

# %%
# the feature sets are 2000 words long - so this is optional
print(featuresets[0])
# Out:
# ({'V_,': True, 'V_the': True, 'V_.': True, 'V_a': True, 'V_and': True, 'V_of': True, 'V_to': True, "V_'": True, 'V_is': True, 'V_in': True, 'V_s': True, 'V_"': True, 'V_it': True, 'V_that': True, 'V_-': True, 'V_)': True, 'V_(': True, 'V_as': True, 'V_with': True, 'V_for': True, 'V_his': True, 'V_this': True, 'V_film': True, 'V_i': True, 'V_he': True, 'V_but': True, 'V_on': True, 'V_are': True, 'V_t': True, 'V_by': True, 'V_be': True, 'V_one': True, 'V_movie': True, 'V_an': True, 'V_who': True, 'V_not': True, 'V_you': True, 'V_from': True, 'V_at': True, 'V_was': True, 'V_have': True, 'V_they': True, 'V_has': True, 'V_her': True, 'V_all': True, 'V_?': True, 'V_there': False, 'V_like': False, 'V_so': True, 'V_out': True, 'V_about': True, 'V_up': False, 'V_more': True, 'V_what': True, 'V_when': True, 'V_which': True, 'V_or': True, 'V_she': True, 'V_their': False, 'V_:': True, 'V_some': False, 'V_just': True, 'V_can': True, 'V_if': True, 'V_we': False, 'V_him': True, 'V_into': False, 'V_even': False, 'V_only': True, 'V_than': True, 'V_no': True, 'V_good': True, 'V_time': False, 'V_most': True, 'V_its': False, 'V_will': True, 'V_story': False, 'V_would': True, 'V_been': True, 'V_much': False, 'V_character': True, 'V_also': False, 'V_get': True, 'V_other': True, 'V_do': False, 'V_two': True, 'V_well': True, 'V_them': False, 'V_very': False, 'V_characters': True, 'V_;': False, 'V_first': True, 'V_--': False, 'V_after': True, 'V_see': True, 'V_!': False, 'V_way': False, 'V_because': False, 'V_make': True, 'V_life': False, 'V_off': False, 'V_too': False, 'V_any': False, 'V_does': True, 'V_really': False, 'V_had': False, 'V_while': False, 'V_films': False, 'V_how': False, 'V_plot': True, 'V_little': False, 'V_where': True, 'V_people': False, 'V_over': False, 'V_could': True, 'V_then': False, 'V_me': False, 'V_scene': True, 'V_man': False, 'V_bad': False, 'V_my': True, 'V_never': True, 'V_being': True, 'V_best': False, 'V_these': True, 'V_don': True, 'V_new': False, 'V_doesn': True, 'V_scenes': False, 'V_many': True, 'V_director': False, 'V_such': False, 'V_know': True, 'V_were': True, 'V_movies': False, 'V_through': True, 'V_here': True, 'V_action': False, 'V_great': True, 'V_re': False, 'V_another': True, 'V_love': True, 'V_go': True, 'V_made': False, 'V_us': False, 'V_big': False, 'V_end': True, 'V_something': False, 'V_back': False, 'V_*': False, 'V_still': False, 'V_world': False, 'V_seems': False, 'V_work': False, 'V_those': False, 'V_makes': True, 'V_now': False, 'V_before': True, 'V_however': False, 'V_between': True, 'V_few': False, 'V_/': False, 'V_down': False, 'V_every': False, 'V_though': False, 'V_better': True, 'V_real': False, 'V_audience': True, 'V_enough': False, 'V_seen': False, 'V_take': True, 'V_around': False, 'V_both': True, 'V_going': False, 'V_year': False, 'V_performance': False, 'V_why': True, 'V_should': False, 'V_role': False, 'V_isn': True, 'V_same': False, 'V_old': False, 'V_gets': False, 'V_your': True, 'V_may': False, 'V_things': True, 'V_think': True, 'V_years': False, 'V_last': True, 'V_comedy': True, 'V_funny': True, 'V_actually': False, 'V_ve': False, 'V_long': False, 'V_look': True, 'V_almost': False, 'V_own': False, 'V_thing': False, 'V_fact': True, 'V_nothing': True, 'V_say': False, 'V_right': False, 'V_john': False, 'V_although': False, 'V_played': False, 'V_find': False, 'V_script': True, 'V_come': True, 'V_ever': True, 'V_cast': False, 'V_since': False, 'V_did': False, 'V_star': True, 'V_plays': False, 'V_young': False, 'V_show': True, 'V_comes': False, 'V_m': False, 'V_part': False, 'V_original': True, 'V_actors': False, 'V_screen': False, 'V_without': False, 'V_again': False, 'V_acting': True, 'V_three': True, 'V_day': True, 'V_each': False, 'V_point': True, 'V_lot': False, 'V_least': False, 'V_takes': True, 'V_guy': False, 'V_quite': True, 'V_himself': False, 'V_away': False, 'V_during': False, 'V_family': False, 'V_effects': False, 'V_course': True, 'V_goes': True, 'V_minutes': False, 'V_int ...

# %%
# training using naive Baysian classifier with a 95/5 split
train_set, test_set = featuresets[100:], featuresets[:100]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
# evaluate the accuracy of the classifier
print (nltk.classify.accuracy(classifier, test_set))
# the accuracy result may vary since we randomized the documents
# Out:
# 0.86

# %%
# show which features of classifier are most informative
print(classifier.show_most_informative_features(30))
# Out:
# Most Informative Features
#            V_outstanding = True              pos : neg    =     10.4 : 1.0
#                  V_mulan = True              pos : neg    =      8.4 : 1.0
#                 V_seagal = True              neg : pos    =      7.7 : 1.0
#            V_wonderfully = True              pos : neg    =      6.3 : 1.0
#                  V_damon = True              pos : neg    =      6.2 : 1.0
#                 V_wasted = True              neg : pos    =      5.6 : 1.0
#             V_ridiculous = True              neg : pos    =      5.4 : 1.0
#                  V_awful = True              neg : pos    =      5.3 : 1.0
#                  V_waste = True              neg : pos    =      5.2 : 1.0
#                   V_lame = True              neg : pos    =      5.1 : 1.0
#                  V_flynt = True              pos : neg    =      5.0 : 1.0
#                 V_poorly = True              neg : pos    =      4.8 : 1.0
#                 V_allows = True              pos : neg    =      4.5 : 1.0
#                    V_era = True              pos : neg    =      4.5 : 1.0
#                  V_worst = True              neg : pos    =      4.4 : 1.0
#                   V_jedi = True              pos : neg    =      4.1 : 1.0
#                   V_dull = True              neg : pos    =      4.1 : 1.0
#                V_unfunny = True              neg : pos    =      4.1 : 1.0
#                  V_bland = True              neg : pos    =      4.1 : 1.0
#                   V_mess = True              neg : pos    =      4.0 : 1.0
#              V_portrayal = True              pos : neg    =      3.9 : 1.0
#                 V_stupid = True              neg : pos    =      3.9 : 1.0
#              V_memorable = True              pos : neg    =      3.9 : 1.0
#              V_laughable = True              neg : pos    =      3.8 : 1.0
#              V_pointless = True              neg : pos    =      3.7 : 1.0
#              V_excellent = True              pos : neg    =      3.6 : 1.0
#              V_fantastic = True              pos : neg    =      3.6 : 1.0
#                 V_subtle = True              pos : neg    =      3.5 : 1.0
#                  V_badly = True              neg : pos    =      3.5 : 1.0
#               V_terrific = True              pos : neg    =      3.5 : 1.0
# None
